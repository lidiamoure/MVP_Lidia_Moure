-- %% [markdown]
-- ## Neste notebook, será feita a segunda parte da análise dos dados do modelo previamente criado.

-- %% [markdown]
-- _Serão dispostas as perguntas e, em seguida, será feita a análise dos dados nas células de modo a respondê-las._
--
-- _Em seguida, caso seja pertinente, serão feitos comentário sobre os resultados encontrados._
--
-- _Obs: Todas as análises feitas sobre os entrevistados cuja idade está entre 15 e 25 anos._

-- %% [markdown]
-- ### Todas as perguntas serão respondidas em cima de dois espaços amostrais:
-- #### 1. 10 países em que houve maior **crescimento percentual recente** (entre as waves 6 e 7) de Católicos Romanos. (Grupo 1)
-- #### 2. 10 países em que houve maior crescimento percentual recente de Católicos Romanos em relação ao montante "Católicos Romanos + Protestantes". (Grupo 2)
--
-- ### Para isso, serão utilizadas, respectivamente, as views criadas: _"mvp_wvs.gold.v_top10_countries_recent_growth_catholicism"_ e _"mvp_wvs.gold.v_top10_countries_recent_growth_catholicismxprotestantisms"_

-- %% [markdown]
-- # Sumário das perguntas respondidas neste notebook
--
-- ### 5. Valores sobre homossexualidade.
--
--  _5.1 O que se observa sobre a tolerância a homosexualidade ao longo das waves? E quanto ao período mais recente (entre as waves 6 e 7)?_
--
-- ### 6. Valores religiosos.
--  _6.1 O que se observa sobre os valores religiosos ao longo das waves? E quanto ao período mais recente (entre as waves 6 e 7)?_
--
-- ### 7. Valores sobre o papel da mulher na sociedade
--  _7.1 O que se observa das opiniões sobre o papel da mulher na sociedade ao longo das waves? E quanto ao período mais recente (entre as waves 6 e 7)?_
--
-- ### 8. Valores conversavadores num geral
--  _8.1 O que se observa sobre as opiniões sobre divórcio, eutanásia, aborto e prostituição ao longo das waves? E quanto ao período mais recente (entre as waves 6 e 7)?_

-- %% [markdown]
-- ## 5. Valores sobre homosexualidade

-- %% [markdown]
-- ### 5.1 O que se observa sobre a tolerância a homosexualidade ao longo das waves? E quanto ao período mais recente (entre as waves 6 e 7)?

-- %% [markdown]
-- _Os códigos abaixo retornam o percentual de pessoas que mencionaram se incomodariam em ter vizinhos homossexuais_

-- %%
-- 10 países em que houve maior crescimento percentual recente de Católicos Romanos em relação ao montante "Católicos Romanos + Protestantes"
select
  fa.wave_chronology,
  fa.neighbors_homosexuals,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicismxprotestantism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.neighbors_homosexuals
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %%
--10 países em que houve maior crescimento percentual recente (entre as waves 6 e 7) de Católicos Romanos.
select
  fa.wave_chronology,
  fa.neighbors_homosexuals,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.neighbors_homosexuals
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %% [markdown]
-- _Os códigos abaixo mostram o percentual de pessoas que consideram a homossexualidade "Nunca Justificável"_

-- %%
--10 países em que houve maior crescimento percentual recente de Católicos Romanos em relação ao montante "Católicos Romanos + Protestantes"
select
  fa.wave_chronology,
  fa.justifiable_homosexuality,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicismxprotestantism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.justifiable_homosexuality
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %%
--10 países em que houve maior crescimento percentual recente (entre as waves 6 e 7) de Católicos Romanos. 
select
  fa.wave_chronology,
  fa.justifiable_homosexuality,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.justifiable_homosexuality
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %% [markdown]
-- 5.1 Comentário:
--
-- _Ao longo das waves, observa-se um **aumento geral da tolerância à homossexualidade** em ambos os grupos, evidenciado pela redução do percentual de respondentes que rejeitam vizinhos homossexuais e que consideram a homossexualidade “nunca justificável”. Essa tendência é mais estável no Grupo 2, que apresenta queda consistente da intolerância e manutenção de níveis mais baixos nas waves finais. O Grupo 1, apesar de partir de patamares mais elevados e exibir maior oscilação, também mostra redução relevante a partir da wave 5. No período mais recente (waves 6 e 7), não há indícios de retrocesso significativo, sugerindo consolidação de atitudes relativamente mais tolerantes, sobretudo no Grupo 2._

-- %% [markdown]
-- ## 6. Valores religiosos

-- %% [markdown]
-- ### 6.1 O que se observa sobre os valores religiosos ao longo das waves? E quanto ao período mais recente (entre as waves 6 e 7)?

-- %% [markdown]
-- _Os códigos abaixo mostram o percentual de pessoas que consideram a religião muito importante_

-- %%
-- 10 países em que houve maior crescimento percentual recente de Católicos Romanos em relação ao montante "Católicos Romanos + Protestantes"

select
  fa.wave_chronology,
  fa.important_religion,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.important_religion
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %%
-- 10 países em que houve maior crescimento percentual recente (entre as waves 6 e 7) de Católicos Romanos.

select
  fa.wave_chronology,
  fa.important_religion,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.important_religion
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %% [markdown]
-- _Os códigos abaixo mostram o percentual de pessoas que se declararam "pessoas religiosas"_

-- %%
--10 países em que houve maior crescimento percentual recente (entre as waves 6 e 7) de Católicos Romanos.
select
  fa.wave_chronology,
  fa.religious_person,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.religious_person
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %%
--10 países em que houve maior crescimento percentual recente de Católicos Romanos em relação ao montante "Católicos Romanos + Protestantes"
select
  fa.wave_chronology,
  fa.religious_person,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicismxprotestantism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.religious_person
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %% [markdown]
-- _Os códigos abaixo mostram o percentual de pessoas que mencionaram que a "fé religiosa" é um qualidade a ser ensidada as crianças em casa._

-- %%
-- 10 países em que houve maior crescimento percentual recente de Católicos Romanos em relação ao montante "Católicos Romanos + Protestantes"
select
  fa.wave_chronology,
  fa.child_religious_faith,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicismxprotestantism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.child_religious_faith
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %%
-- 10 países em que houve maior crescimento percentual recente (entre as waves 6 e 7) de Católicos Romanos.
select
  fa.wave_chronology,
  fa.child_religious_faith,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.child_religious_faith
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %% [markdown]
-- _Os códigos abaixo mostram o % de pessoas que consideram Deus "muito importante" em suas vidas._

-- %%
--10 países em que houve maior crescimento percentual recente (entre as waves 6 e 7) de Católicos Romanos.
select
  fa.wave_chronology,
  fa.importance_god,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.importance_god
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %%
--10 países em que houve maior crescimento percentual recente de Católicos Romanos em relação ao montante "Católicos Romanos + Protestantes"
select
  fa.wave_chronology,
  fa.importance_god,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicismxprotestantism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.importance_god
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %% [markdown]
-- _Os códigos abaixo mostram o % de pessoas que vão a cultos religiosos "uma vez na semana"._

-- %%
-- 10 países em que houve maior crescimento percentual recente de Católicos Romanos em relação ao montante "Católicos Romanos + Protestantes"
select
  fa.wave_chronology,
  fa.attendance_services,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicismxprotestantism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.attendance_services
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %%
-- 10 países em que houve maior crescimento percentual recente (entre as waves 6 e 7) de Católicos Romanos.
select
  fa.wave_chronology,
  fa.attendance_services,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.attendance_services
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %% [markdown]
-- 6.1 Comentário
--
-- Ao longo das waves, observa-se que os **valores religiosos apresentam tendência geral de enfraquecimento**, especialmente a partir da wave 5, em ambos os grupos. Embora o Grupo 1 mantenha níveis sistematicamente mais elevados em todos os indicadores — importância da religião, autodeclaração como pessoa religiosa, centralidade de Deus e transmissão da fé às crianças —, nota-se uma redução progressiva desses percentuais ao longo do tempo. O Grupo 2, por sua vez, parte de patamares mais baixos e exibe maior volatilidade, mas também apresenta queda consistente nos indicadores religiosos.
--
-- No período mais recente (waves 6 e 7), os dados sugerem **estabilidade em níveis mais baixos**, sem retorno aos valores elevados observados nas waves iniciais. A frequência semanal a cultos, em particular, permanece reduzida e relativamente estável, indicando que o declínio observado não se limita a crenças declaradas, mas também se reflete nas práticas religiosas. Em conjunto, os resultados apontam para um processo de r**edução gradual da centralidade da religião, mais intenso no Grupo 2**, mas presente em ambos os grupos.

-- %% [markdown]
-- ## 7 .Valores sobre o papel da mulher na sociedade

-- %% [markdown]
-- ### 7.1 O que se observa das opiniões sobre o papel da mulher na sociedade ao longo das waves? E quanto ao período mais recente (entre as waves 6 e 7)?

-- %% [markdown]
-- _Os códigos abaixo mostram o % de pessoas que **concordam** que homens são melhores líderes políticos que mulheres._

-- %%
--10 países em que houve maior crescimento percentual recente de Católicos Romanos em relação ao montante "Católicos Romanos + Protestantes"
select
  fa.wave_chronology,
  fa.men_better_leaders,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicismxprotestantism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.men_better_leaders
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %%
--10 países em que houve maior crescimento percentual recente (entre as waves 6 e 7) de Católicos Romanos.
select
  fa.wave_chronology,
  fa.men_better_leaders,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.men_better_leaders
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %% [markdown]
-- _Os códigos abaixo mostram o % de pessoas que **concordam** que ser dona de casa é tão gratificante quanto trabalhar fora._

-- %%
--10 países em que houve maior crescimento percentual recente de Católicos Romanos em relação ao montante "Católicos Romanos + Protestantes"

select
  fa.wave_chronology,
  fa.housewife_fulfilling,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicismxprotestantism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.housewife_fulfilling
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %%
--10 países em que houve maior crescimento percentual recente (entre as waves 6 e 7) de Católicos Romanos.
select
  fa.wave_chronology,
  fa.housewife_fulfilling,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.housewife_fulfilling
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %% [markdown]
-- _Os códigos abaixo mostram o % de pessoas que **concordam** que a universidade é mais importante para os meninos do que para as meninas._

-- %%
-- 10 países em que houve maior crescimento percentual recente de Católicos Romanos em relação ao montante "Católicos Romanos + Protestantes"
select
  fa.wave_chronology,
  fa.university_more_for_boys,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicismxprotestantism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.university_more_for_boys
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %%
-- 10 países em que houve maior crescimento percentual recente (entre as waves 6 e 7) de Católicos Romanos.
select
  fa.wave_chronology,
  fa.university_more_for_boys,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.university_more_for_boys
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %% [markdown]
-- _Os códigos abaixo mostram o % de pessoas que "concordam fortemente" que, em caso de escassez de empregos, os homens devem ter prioridade em relação às mulheres._

-- %%
-- 10 países em que houve maior crescimento percentual recente de Católicos Romanos em relação ao montante "Católicos Romanos + Protestantes"

select
  fa.wave_chronology,
  fa.men_priority_jobs,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicismxprotestantism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.men_priority_jobs
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %%
-- 10 países em que houve maior crescimento percentual recente (entre as waves 6 e 7) de Católicos Romanos.

select
  fa.wave_chronology,
  fa.men_priority_jobs,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.men_priority_jobs
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %% [markdown]
-- 7.1 Comentário
--
-- _Ao longo das waves, as opiniões sobre o papel da mulher mostram estabilidade com oscilações moderadas, com o **Grupo 1 apresentando níveis consistentemente mais altos de concordância com visões tradicionais de gênero**. Entre as waves 6 e 7, não há mudanças relevantes, prevalecendo estabilidade ou leve redução dessas posições, o que indica manutenção das diferenças entre os grupos no período mais recente._

-- %% [markdown]
-- ## 8. Valores conservadores num geral

-- %% [markdown]
-- ### 8.1 O que se observa sobre as opiniões sobre divórcio, eutanásia, aborto e prostituição ao longo das waves? E quanto ao período mais recente (entre as waves 6 e 7)?

-- %% [markdown]
-- _Os códigos abaixo mostram o % de pessoas que consideram o aborto "nunca justificável"._

-- %%
-- 10 países em que houve maior crescimento percentual recente de Católicos Romanos em relação ao montante "Católicos Romanos + Protestantes"
select
  fa.wave_chronology,
  fa.justifiable_abortion,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicismxprotestantism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.justifiable_abortion
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %%
-- 10 países em que houve maior crescimento percentual recente (entre as waves 6 e 7) de Católicos Romanos.
select
  fa.wave_chronology,
  fa.justifiable_abortion,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.justifiable_abortion
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %% [markdown]
-- _Os códigos abaixo mostram o % de pessoas que consideram o divórcio "nunca justificável"._

-- %%
-- 10 países em que houve maior crescimento percentual recente de Católicos Romanos em relação ao montante "Católicos Romanos + Protestantes"

select
  fa.wave_chronology,
  fa.justifiable_divorce,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicismxprotestantism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.justifiable_divorce
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %%
-- 10 países em que houve maior crescimento percentual recente (entre as waves 6 e 7) de Católicos Romanos.

select
  fa.wave_chronology,
  fa.justifiable_divorce,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.justifiable_divorce
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %% [markdown]
-- _Os códigos abaixo mostram o % de pessoas que consideram a eutanásia "nunca justificável"._

-- %%
--10 países em que houve maior crescimento percentual recente de Católicos Romanos em relação ao montante "Católicos Romanos + Protestantes"
select
  fa.wave_chronology,
  fa.justifiable_euthanasia,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicismxprotestantism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.justifiable_euthanasia
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %%
--10 países em que houve maior crescimento percentual recente (entre as waves 6 e 7) de Católicos Romanos.
select
  fa.wave_chronology,
  fa.justifiable_euthanasia,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.justifiable_euthanasia
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %% [markdown]
-- _O código abaixo mostra o % de pessoas que consideram a prostituição "nunca justificável"._

-- %%
--10 países em que houve maior crescimento percentual recente de Católicos Romanos em relação ao montante "Católicos Romanos + Protestantes"
select
  fa.wave_chronology,
  fa.justifiable_prostitution,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicismxprotestantism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.justifiable_prostitution
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %%
-- 10 países em que houve maior crescimento percentual recente (entre as waves 6 e 7) de Católicos Romanos.
select
  fa.wave_chronology,
  fa.justifiable_prostitution,
  count(*) * 100.0 / sum(count(*)) over (partition by fa.wave_chronology) as response_percentage
from mvp_wvs.gold.fact_wave_all fa
join mvp_wvs.gold.dim_age da
  on fa.age = da.age
join mvp_wvs.gold.dim_age_range ar
  on da.age_range = ar.age_range
join mvp_wvs.gold.dim_country dc
  on fa.country_code = dc.country_code
join mvp_wvs.gold.v_top10_countries_recent_growth_catholicism vtc
  on dc.Country = vtc.country
where ar.age_range = '15 - 25 years old'
group by fa.wave_chronology, fa.justifiable_prostitution
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %% [markdown]
-- 8.1 Comentário
--
-- _Ao longo das waves, as opiniões sobre aborto, divórcio, eutanásia e prostituição apresentam oscilações relevantes, **sem tendência linear clara**, mas com **níveis consistentemente mais elevados de rejeição no Grupo 1**, indicando maior alinhamento a valores conservadores. O Grupo 2, embora também manifeste posições restritivas, apresenta percentuais geralmente mais baixos e maior variabilidade ao longo do tempo._
--
-- _Entre as waves 6 e 7, observa-se estabilidade ou leve aumento da rejeição em alguns temas, sem retorno aos picos observados nas waves iniciais. No conjunto, o período mais recente sugere manutenção de posições conservadoras, com diferenças persistentes entre os grupos e ausência de mudança estrutural significativa._

-- %% [markdown]
-- Comentário geral:
--
-- _De modo geral, **o Grupo 1 apresenta valores mais tradicionais e conservadores em todas as dimensões analisadas**, com maior religiosidade, maior adesão a papéis de gênero tradicionais e maior rejeição a temas morais controversos._
--
-- _**O Grupo 2**, por sua vez, **tende a posições relativamente mais tolerantes e menos religiosas**, ainda que com oscilações ao longo das waves._
--
--  _Em ambos os grupos, observa-se redução da centralidade da religião e aumento da tolerância à homossexualidade, enquanto as opiniões sobre o papel da mulher e temas morais mostram maior estabilidade. No conjunto, os resultados indicam persistência das diferenças entre os grupos, sem evidências de mudança estrutural recente._
