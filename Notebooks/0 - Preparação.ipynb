-- %%
%sql
DROP CATALOG IF EXISTS MVP_WVS CASCADE

-- %%
%sql
create catalog MVP_WVS

-- %%
use catalog mvp_wvs

-- %%
create schema staging

-- %%
create schema bronze

-- %%
create schema silver

-- %%
create schema gold
